# %% [markdown]
# # ACE-Net Universal Shard Preprocessor (One-Pass Suite)
# ### Assigned Member: **EL (Account 4)**
# ### Target Account: `geueljohn.rivera.lexmeet@gmail.com`
# ### Target Dataset: **MELD** | Shard: **`shard_0004`**
# ### Output Target: `Google Drive > THESIS_MOTHERFILE > Baseline preprocessed > MELD`

# %% [markdown]
# ## Step 1: Connect to GPU & Mount Google Drive

# %%
from google.colab import drive
import os, sys, torch

drive.mount('/content/drive')
print('GPU Available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('Device:', torch.cuda.get_device_name(0))

# %% [markdown]
# ## Step 2: Clone Repository & Checkout Branch

# %%
# %cd /content
# !rm -rf Baseline_Training
# !git clone https://github.com/gjvlio/Baseline_Training.git
# %cd Baseline_Training
# !git checkout feat/baseline-preprocessing-jc
# !git pull
# !git log --oneline -1

# %% [markdown]
# ## Step 3: Install Required Dependencies

# %%
# !pip install -q --no-deps facenet-pytorch
# !pip install -q --no-deps git+https://github.com/openai/whisper.git
print('Dependencies installed successfully!')

# %% [markdown]
# ## Step 4: Fast Unzip Raw Dataset (`meld_raw.zip`) to Local Colab SSD

# %%
import os

DRIVE_ZIP = '/content/drive/MyDrive/THESIS_MOTHERFILE/datasets/meld_raw.zip'
LOCAL_RAW = '/content/data/raw/MELD'

os.makedirs(LOCAL_RAW, exist_ok=True)
if not os.path.exists(DRIVE_ZIP):
    raise FileNotFoundError(f'Raw zip not found in Drive: {DRIVE_ZIP}')

print(f'Fast unzipping {DRIVE_ZIP} to local SSD ({LOCAL_RAW})...')
# !unzip -q -n '{DRIVE_ZIP}' -d '{LOCAL_RAW}'
print('Unzip complete! Local files ready.')

# %% [markdown]
# ## Step 5: Execute Preprocessing for `MELD` [shard_0004]

# %%
# !python scripts/preprocess/run_shard.py \
    --account 'geueljohn.rivera.lexmeet@gmail.com' \
    --dataset 'MELD' \
    --shard '0004' \
    --raw_dir '/content/data/raw/MELD' \
    --drive_root '/content/drive/MyDrive/THESIS_MOTHERFILE' \
    --device cuda

# %% [markdown]
# ## Step 6: Post-Run Integrity Check & Verification

# %%
import json, glob
from pathlib import Path

ckpt_file = Path('/content/drive/MyDrive/THESIS_MOTHERFILE/Baseline preprocessed/MELD/checkpoints/shard_0004_checkpoint.json')
out_shard = Path('/content/drive/MyDrive/THESIS_MOTHERFILE/Baseline preprocessed/MELD/shards/shard_0004')

if ckpt_file.exists():
    with open(ckpt_file) as f:
        data = json.load(f)
    print('=' * 60)
    print('SHARD STATUS:', data.get('status'))
    print('Completed Clips:', len(data.get('completed_ids', [])))
    print('Failed Clips   :', len(data.get('failed_ids', [])))
    print('=' * 60)
else:
    print('Checkpoint not found. Run Step 5 first.')
